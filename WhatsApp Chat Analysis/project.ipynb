# %%
import re
import pandas as pd

# %%
f = open('WhatsApp Chat with BCA-Students-2022-25.txt', 'r', encoding='utf-8')

# %%
data = f.read()

# %%
print(data)
# Out:
# 10/31/22, 4:20 PM - Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.
# 10/31/22, 4:20 PM - BCIIT created group "BCA-Students-2022-25"
# 10/31/22, 4:20 PM - BCIIT added you
# 10/31/22, 4:21 PM - BCIIT added ~ Aniket Singhal
# 10/31/22, 4:21 PM - BCIIT added ~ Anmol Dhingra
# 10/31/22, 4:23 PM - BCIIT added ~ .
# 10/31/22, 4:24 PM - BCIIT added ~ Piyush Pal
# 10/31/22, 4:45 PM - BCIIT added विनीत, ~ Pratham Kumar Singh, and +91 82659 58322
# 10/31/22, 4:48 PM - BCIIT added ~ Sumati🧿
# 10/31/22, 4:49 PM - BCIIT added ~ Bhavya
# 10/31/22, 4:50 PM - BCIIT added ~ Himanshu Jha
# 10/31/22, 5:01 PM - BCIIT added Sandeep Sir BCIIT, Susma BCIIT, ~ Amit Shrivastav, ~ God Is Great, ~ Nupur, ~ Punaam, ~ Ravish Saggar, ~ Richard, ~ Sonia, +91 85068 48161, and +91 95827 49622
# 10/31/22, 5:02 PM - BCIIT: This message was deleted
# 10/31/22, 5:03 PM - BCIIT: Dear Student,
#
# Congratulations!!
#
# Greetings from BCIIT!!
#
# ...

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
# regex101.com

pattern = r'\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s?[APMapm]{2}\s-\s'

# Here we divide the data into 3 parts i.e. Date, Time and Message

# %%
messages = re.split(pattern, data)[1:]

messages
# Out:
# ['Messages and calls are end-to-end encrypted. Only people in this chat can read, listen to, or share them. Learn more.\n',
#  'BCIIT created group "BCA-Students-2022-25"\n',
#  'BCIIT added you\n',
#  'BCIIT added ~\u202fAniket Singhal\n',
#  'BCIIT added ~\u202fAnmol Dhingra\n',
#  'BCIIT added ~\u202f.\n',
#  'BCIIT added ~\u202fPiyush Pal\n',
#  'BCIIT added विनीत, ~\u202fPratham Kumar Singh, and +91 82659 58322\n',
#  'BCIIT added ~\u202fSumati🧿\n',
#  'BCIIT added ~\u202fBhavya\n',
#  'BCIIT added ~\u202fHimanshu Jha\n',
#  'BCIIT added Sandeep Sir BCIIT, Susma BCIIT, ~\u202fAmit Shrivastav, ~\u202fGod Is Great, ~\u202fNupur, ~\u202fPunaam, ~\u202fRavish Saggar, ~\u202fRichard, ~\u202fSonia, +91 85068 48161, and +91 95827 49622\n',
#  'BCIIT: This message was deleted\n',
# ...

# %%
dates = re.findall(pattern, data)

dates
# Out:
# ['10/31/22, 4:20\u202fPM - ',
#  '10/31/22, 4:20\u202fPM - ',
#  '10/31/22, 4:20\u202fPM - ',
#  '10/31/22, 4:21\u202fPM - ',
#  '10/31/22, 4:21\u202fPM - ',
#  '10/31/22, 4:23\u202fPM - ',
#  '10/31/22, 4:24\u202fPM - ',
#  '10/31/22, 4:45\u202fPM - ',
#  '10/31/22, 4:48\u202fPM - ',
#  '10/31/22, 4:49\u202fPM - ',
#  '10/31/22, 4:50\u202fPM - ',
#  '10/31/22, 5:01\u202fPM - ',
#  '10/31/22, 5:02\u202fPM - ',
#  '10/31/22, 5:03\u202fPM - ',
#  '10/31/22, 6:54\u202fPM - ',
#  '10/31/22, 6:56\u202fPM - ',
#  '10/31/22, 7:00\u202fPM - ',
#  '10/31/22, 7:01\u202fPM - ',
#  '10/31/22, 7:03\u202fPM - ',
#  '10/31/22, 7:06\u202fPM - ',
#  '10/31/22, 8:37\u202fPM - ',
#  '10/31/22, 9:02\u202fPM - ',
#  '10/31/22, 9:02\u202fPM - ',
#  '10/31/22, 9:03\u202fPM - ',
#  '10/31/22, 9:04\u202fPM - ',
#  '10/31/22, 9:04\u202fPM - ',
#  '10/31/22, 9:04\u202fPM - ',
#  '10/31/22, 9:04\u202fPM - ',
#  '10/31/22, 9:05\u202fPM - ',
#  '10/31/22, 9:10\u202fPM - ',
#  '10/31/22, 9:52\u202fPM - ',
# ...

# %%
df = pd.DataFrame({'user_message': messages, 'message_date': dates})

# Convert message_data type

df['message_date'] = pd.to_datetime(df['message_date'], format='%m/%d/%y, %I:%M %p - ')

df.rename(columns={'message_date': 'date'}, inplace=True)

df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. O... 2022-10-31 16:20:00
# 1       BCIIT created group "BCA-Students-2022-25"\n 2022-10-31 16:20:00
# 2                                  BCIIT added you\n 2022-10-31 16:20:00
# 3                     BCIIT added ~ Aniket Singhal\n 2022-10-31 16:21:00
# 4                      BCIIT added ~ Anmol Dhingra\n 2022-10-31 16:21:00

# %%
df.shape
# Out:
# (3903, 2)

# %%
# Seperate Users and Messages

users = []
messages = []

for message in df['user_message']:
    entry = re.split(r'([\w\W]+?):\s', message)
    if entry[1:]: # User name
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append("group_notification")
        messages.append(entry[0])

df['user'] = users
df['message'] = messages

df.drop(columns=['user_message'], inplace=True)

df.head()
# Out:
#                  date                user  \
# 0 2022-10-31 16:20:00  group_notification
# 1 2022-10-31 16:20:00  group_notification
# 2 2022-10-31 16:20:00  group_notification
# 3 2022-10-31 16:21:00  group_notification
# 4 2022-10-31 16:21:00  group_notification
#
#                                              message
# 0  Messages and calls are end-to-end encrypted. O...
# 1       BCIIT created group "BCA-Students-2022-25"\n
# 2                                  BCIIT added you\n
# 3                     BCIIT added ~ Aniket Singhal\n
# 4                      BCIIT added ~ Anmol Dhingra\n

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month_name()
df['day'] = df['date'].dt.day
df['hour'] = df['date'].dt.hour
df['minute'] = df['date'].dt.minute

df.head()
# Out:
#                  date                user  \
# 0 2022-10-31 16:20:00  group_notification
# 1 2022-10-31 16:20:00  group_notification
# 2 2022-10-31 16:20:00  group_notification
# 3 2022-10-31 16:21:00  group_notification
# 4 2022-10-31 16:21:00  group_notification
#
#                                              message  year    month  day  \
# 0  Messages and calls are end-to-end encrypted. O...  2022  October   31
# 1       BCIIT created group "BCA-Students-2022-25"\n  2022  October   31
# 2                                  BCIIT added you\n  2022  October   31
# 3                     BCIIT added ~ Aniket Singhal\n  2022  October   31
# 4                      BCIIT added ~ Anmol Dhingra\n  2022  October   31
#
#    hour  minute
# 0    16      20
# 1    16      20
# 2    16      20
# 3    16      21
# 4    16      21

# %%
df[df['user'] == 'BCIIT'].shape
# Out:
# (667, 8)

# %%
words = []
for message in df['message']:
    words.extend(message.split())

len(words)
# Out:
# 46613

# %%
df.head(5)
# Out:
#                  date                user  \
# 0 2022-10-31 16:20:00  group_notification
# 1 2022-10-31 16:20:00  group_notification
# 2 2022-10-31 16:20:00  group_notification
# 3 2022-10-31 16:21:00  group_notification
# 4 2022-10-31 16:21:00  group_notification
#
#                                              message  year    month  day  \
# 0  Messages and calls are end-to-end encrypted. O...  2022  October   31
# 1       BCIIT created group "BCA-Students-2022-25"\n  2022  October   31
# 2                                  BCIIT added you\n  2022  October   31
# 3                     BCIIT added ~ Aniket Singhal\n  2022  October   31
# 4                      BCIIT added ~ Anmol Dhingra\n  2022  October   31
#
#    hour  minute
# 0    16      20
# 1    16      20
# 2    16      20
# 3    16      21
# 4    16      21

# %%
df[df['message'] == '<Media omitted>\n'].shape[0]
# Out:
# 629

# %%
print(df)
# Out:
#                     date                user  \
# 0    2022-10-31 16:20:00  group_notification
# 1    2022-10-31 16:20:00  group_notification
# 2    2022-10-31 16:20:00  group_notification
# 3    2022-10-31 16:21:00  group_notification
# 4    2022-10-31 16:21:00  group_notification
# ...                  ...                 ...
# 3898 2025-10-29 12:14:00     +91 78384 84806
# 3899 2025-10-30 15:51:00               BCIIT
# 3900 2025-11-01 18:34:00  group_notification
# 3901 2025-11-02 10:20:00  group_notification
# 3902 2025-11-03 14:29:00  group_notification
#
#                                                 message  year     month  day  \
# 0     Messages and calls are end-to-end encrypted. O...  2022   October   31
# 1          BCIIT created group "BCA-Students-2022-25"\n  2022   October   31
# 2                                     BCIIT added you\n  2022   October   31
# 3                        BCIIT added ~ Aniket Singhal\n  2022   October   31
# ...

# %%
from urlextract import URLExtract

extract = URLExtract()

urls = extract.find_urls("Let's go to https://www.google.com ! And https://www.youtube.com")

urls
# Out:
# ['https://www.google.com', 'https://www.youtube.com']

# %%
y = []
for message in df['message']:
    y.extend(extract.find_urls(message))

# %%
len(y)
# Out:
# 163

# %%
df.head()
# Out:
#                  date                user  \
# 0 2022-10-31 16:20:00  group_notification
# 1 2022-10-31 16:20:00  group_notification
# 2 2022-10-31 16:20:00  group_notification
# 3 2022-10-31 16:21:00  group_notification
# 4 2022-10-31 16:21:00  group_notification
#
#                                              message  year    month  day  \
# 0  Messages and calls are end-to-end encrypted. O...  2022  October   31
# 1       BCIIT created group "BCA-Students-2022-25"\n  2022  October   31
# 2                                  BCIIT added you\n  2022  October   31
# 3                     BCIIT added ~ Aniket Singhal\n  2022  October   31
# 4                      BCIIT added ~ Anmol Dhingra\n  2022  October   31
#
#    hour  minute
# 0    16      20
# 1    16      20
# 2    16      20
# 3    16      21
# 4    16      21

# %%
df['user'].value_counts()
# Out:
# user
# BCIIT                 667
# group_notification    476
# +91 99101 36173       401
# Sandeep Sir BCIIT     352
# +91 80768 92297       224
#                      ...
# +91 98995 23466         1
# विनीत                   1
# +91 93548 17643         1
# Abhishek BCA            1
# Priyam Jha              1
# Name: count, Length: 77, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
X = df['user'].value_counts().head()

name = X.index
count = X.values

plt.bar(name, count)
plt.xticks(rotation='vertical')
plt.show()

# %%
df_percent = ((df['user'].value_counts() / df.shape[0]) * 100).round(2).rename_axis('name').reset_index(name='percent')

df_percent
# Out:
#                   name  percent
# 0                BCIIT    17.09
# 1   group_notification    12.20
# 2      +91 99101 36173    10.27
# 3    Sandeep Sir BCIIT     9.02
# 4      +91 80768 92297     5.74
# ..                 ...      ...
# 72     +91 98995 23466     0.03
# 73               विनीत     0.03
# 74     +91 93548 17643     0.03
# 75        Abhishek BCA     0.03
# 76          Priyam Jha     0.03
#
# [77 rows x 2 columns]

# %%
words = []

for message in df['message']:
    words.extend(message.split())

words
# Out:
# ['Messages',
#  'and',
#  'calls',
#  'are',
#  'end-to-end',
#  'encrypted.',
#  'Only',
#  'people',
#  'in',
#  'this',
#  'chat',
#  'can',
#  'read,',
#  'listen',
#  'to,',
#  'or',
#  'share',
#  'them.',
#  'Learn',
#  'more.',
#  'BCIIT',
#  'created',
#  'group',
#  '"BCA-Students-2022-25"',
#  'BCIIT',
#  'added',
#  'you',
#  'BCIIT',
#  'added',
#  '~',
#  'Aniket',
#  'Singhal',
#  'BCIIT',
#  'added',
#  '~',
#  'Anmol',
#  'Dhingra',
#  'BCIIT',
#  'added',
#  '~',
#  '.',
#  'BCIIT',
#  'added',
#  '~',
#  'Piyush',
#  'Pal',
#  'BCIIT',
#  'added',
#  'विनीत,',
#  '~',
#  'Pratham',
#  'Kumar',
#  'Singh,',
#  'and',
#  '+91',
#  '82659',
#  '58322',
#  'BCIIT',
#  'added',
#  '~',
#  'Sumati🧿',
#  'BCIIT',
#  'added',
#  '~',
#  'Bhavya',
#  'BCIIT',
#  'added',
#  '~',
#  'Himanshu',
#  'Jha',
#  'BCIIT',
#  'added',
#  'Sandeep',
#  'Sir',
#  'BCIIT,',
#  'Susma',
#  'BCIIT,',
#  '~',
#  'Amit',
#  'Shrivastav,',
#  '~',
#  'God',
#  'Is',
#  'Great,',
#  '~',
# ...

# %%
from collections import Counter

pd.DataFrame(Counter(words).most_common(20))
# Out:
#            0     1
# 0         to  1420
# 1        the  1268
# 2        for   909
# 3         in   713
# 4        and   677
# 5         of   656
# 6     <Media   629
# 7   omitted>   629
# 8       with   603
# 9       Your   459
# 10       are   453
# 11  students   444
# 12      your   442
# 13        at   439
# 14       Tap   428
# 15      code   424
# 16     more.   421
# 17       you   421
# 18  security   421
# 19     learn   421

# %%
# There are many Stopwords like the, a, an, etc. that we need to remove.
# remove group_notifications
# remove media omitted
# remove stops words

# %%
temp = df[df['user'] != 'group_notification']
temp = temp[temp['message'] != '<Media omitted>\n']
temp = temp[temp['message'] != 'This message was deleted\n']
temp = temp[temp['message'].notna()]  # remove NaN if any
temp
# Out:
#                     date             user  \
# 13   2022-10-31 17:03:00            BCIIT
# 14   2022-10-31 18:54:00  +91 82629 08126
# 17   2022-10-31 19:01:00  +91 80768 92297
# 19   2022-10-31 19:06:00  +91 81302 70920
# 20   2022-10-31 20:37:00  +91 88609 01580
# ...                  ...              ...
# 3885 2025-10-27 17:04:00  +91 78384 84806
# 3886 2025-10-27 17:04:00  +91 78384 84806
# 3887 2025-10-27 17:04:00  +91 78384 84806
# 3888 2025-10-27 17:04:00  +91 78384 84806
# 3899 2025-10-30 15:51:00            BCIIT
#
#                                                 message  year    month  day  \
# 13                                                       2022  October   31
# 14                                                hye\n  2022  October   31
# 17                                                Hlo\n  2022  October   31
# 19                                                 Hi\n  2022  October   31
# ...

# %%
f = open('stop_hinglish.txt', 'r')
stop_words = f.read()
print(stop_words)
# Out:
# .
# ..
# ...
# ?
# -
# --
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 0
# a
# aadi
# aaj
# aap
# aapne
# aata
# aati
# aaya
# aaye
# ab
# abbe
# abbey
# abe
# abhi
# able
# about
# above
# accha
# according
# accordingly
# acha
# achcha
# across
# actually
# after
# afterwards
# again
# against
# agar
# ain
# aint
# ain't
# aisa
# aise
# aisi
# alag
# all
# allow
# allows
# almost
# alone
# along
# already
# also
# although
# always
# am
# among
# amongst
# an
# and
# andar
# another
# any
# anybody
# anyhow
# anyone
# anything
# anyway
# anyways
# anywhere
# ap
# apan
# apart
# apna
# apnaa
# apne
# apni
# appear
# are
# aren
# arent
# aren't
# around
# arre
# as
# aside
# ask
# asking
# at
# aur
# avum
# aya
# aye
# baad
# baar
# bad
# bahut
# bana
# banae
# banai
# banao
# banaya
# banaye
# banayi
# banda
# bande
# bandi
# bane
# bani
# bas
# bata
# batao
# bc
# be
# became
# because
# become
# becomes
# becoming
# been
# before
# beforehand
# behind
# being
# below
# beside
# besides
# ...

# %%
words = []

for message in temp['message']:
    for word in message.lower().split():
        if word not in stop_words:
            words.append(word)

words
# Out:
# ['hye',
#  'hlo',
#  'hii',
#  'kl',
#  'documents',
#  'nhii',
#  'lane',
#  '??',
#  'lana',
#  'bta',
#  'dete',
#  'groupe',
#  'oky',
#  'documents',
#  'brought,',
#  'case,',
#  'student',
#  'pending',
#  'documents',
#  'left',
#  'submit',
#  'tomorrow.',
#  'orientation',
#  'baje',
#  '12',
#  'free',
#  'tomorrow',
#  'mam',
#  'hlo',
#  'wanna',
#  'join',
#  'unofficial',
#  'grp',
#  'kindly',
#  'sabko',
#  'karde',
#  'giving',
#  'link',
#  '🔗join',
#  'excluding',
#  'teachers',
#  'course',
#  'yeahh',
#  'unofficial',
#  'grps',
#  '30',
#  '30',
#  'batenge',
#  'link',
#  'unofficial',
#  'group',
#  'dm',
#  'kro',
#  'yrr',
#  '8:30',
#  'aanna',
#  'kya??',
#  'pta',
#  'table',
#  'baje',
#  'kindly',
#  'baat',
#  'teacher',
#  'student',
#  'no.',
#  'save',
#  'zara',
#  'student',
#  '😂',
#  'schedule',
#  'shared',
#  'mam',
#  'mam',
#  'schedule?',
#  '++',
#  'matlab',
#  'kiska?',
#  '++',
#  'question',
#  'note',
#  'schedule',
#  'tomorrow',
# ...

# %%
from collections import Counter

pd.DataFrame(Counter(words).most_common(20))
# Out:
#                   0    1
# 0          students  665
# 1              dear  280
# 2              note  259
# 3          assemble  244
# 4               lab  220
# 5          tomorrow  186
# 6           lecture  177
# 7         scheduled  170
# 8         requested  159
# 9                pm  152
# 10        students,  139
# 11            today  116
# 12             room  115
# 13         schedule  112
# 14            class   96
# 15  congratulations   96
# 16              mam   95
# 17          classes   93
# 18          college   90
# 19              mca   88

# %%
import emoji

emojis = []

for message in df['message']:
    emojis.extend([c for c in message if c in emoji.EMOJI_DATA])

emojis
# Out:
# ['🧿',
#  '🔗',
#  '😂',
#  '🙂',
#  '👍',
#  '☺',
#  '☺',
#  '🏆',
#  '🏆',
#  '🖤',
#  '❤',
#  '🏸',
#  '☺',
#  '☺',
#  '🏸',
#  '🏆',
#  '🏆',
#  '👏',
#  '👏',
#  '🤔',
#  '🙏',
#  '🏻',
#  '⏲',
#  '☺',
#  '☺',
#  '💐',
#  '☺',
#  '☺',
#  '💐',
#  '💐',
#  '💐',
#  '🌸',
#  '🌸',
#  '💐',
#  '🌸',
#  '🥳',
#  '✨',
#  '🥳',
#  '🥳',
#  '🎉',
#  '♥',
#  '🎉',
#  '😌',
#  '👍',
#  '👍',
#  '👍',
#  '👍',
#  '💐',
#  '👍',
#  '👍',
#  '💐',
#  '🥲',
#  '👍',
#  '👍',
#  '💐',
#  '👍',
#  '🙏',
#  '☺',
#  '☺',
#  '🌸',
#  '😌',
#  '☺',
#  '❤',
#  '😊',
#  '🥰',
#  '🥰',
#  '❤',
#  '👍',
#  '✍',
#  '✨',
#  '🙏',
#  '🙏',
#  '🏻',
#  '🙏',
#  '🏻',
#  '👏',
#  '🏻',
#  '👏',
#  '🏻',
#  '❤',
#  '✨',
#  '👏',
#  '💜',
#  '👏',
#  '👏',
#  '👏',
#  '👏',
#  '👏',
#  '👏',
#  '🙏',
#  '🏻',
#  '🥴',
#  '💎',
#  '💐',
#  '💐',
#  '🙏',
#  '👏',
#  '👏',
#  '👏',
#  '👏',
#  '🙌',
#  '🙌',
#  '👏',
#  '🏻',
#  '👏',
#  '🏻',
#  '👍',
#  '✨',
#  '👍',
#  '✌',
#  '🧿',
#  '👍',
#  '🏻',
#  '👍',
#  '👍',
#  '👍',
#  '🏻',
#  '🙏',
#  '🎉',
#  '🎉',
#  '🎉',
#  '😊',
#  '🧿',
#  '☺',
#  '☺',
# ...

# %%
emoji_df = pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))

# %%
plt.bar(emoji_df[0].head(), emoji_df[1].head())
plt.show()
# Out:
# c:\Users\Priyam\Desktop\ML-Projects\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Priyam\Desktop\ML-Projects\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128079 (\N{CLAPPING HANDS SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Priyam\Desktop\ML-Projects\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127995 (\N{EMOJI MODIFIER FITZPATRICK TYPE-1-2}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Priyam\Desktop\ML-Projects\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127881 (\N{PARTY POPPER}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df['month_sum'] = df['date'].dt.month

# %%
df
# Out:
#                     date                user  \
# 0    2022-10-31 16:20:00  group_notification
# 1    2022-10-31 16:20:00  group_notification
# 2    2022-10-31 16:20:00  group_notification
# 3    2022-10-31 16:21:00  group_notification
# 4    2022-10-31 16:21:00  group_notification
# ...                  ...                 ...
# 3898 2025-10-29 12:14:00     +91 78384 84806
# 3899 2025-10-30 15:51:00               BCIIT
# 3900 2025-11-01 18:34:00  group_notification
# 3901 2025-11-02 10:20:00  group_notification
# 3902 2025-11-03 14:29:00  group_notification
#
#                                                 message  year     month  day  \
# 0     Messages and calls are end-to-end encrypted. O...  2022   October   31
# 1          BCIIT created group "BCA-Students-2022-25"\n  2022   October   31
# 2                                     BCIIT added you\n  2022   October   31
# 3                        BCIIT added ~ Aniket Singhal\n  2022   October   31
# ...

# %%
timeline = df.groupby(['year', 'month', 'month_sum']).count()['message'].reset_index()

# %%
timeline
# Out:
#     year      month  month_sum  message
# 0   2022   December         12       97
# 1   2022   November         11      272
# 2   2022    October         10       33
# 3   2023      April          4      153
# 4   2023     August          8       78
# 5   2023   December         12      123
# 6   2023   February          2       53
# 7   2023    January          1      120
# 8   2023       July          7       48
# 9   2023       June          6      104
# 10  2023      March          3      144
# 11  2023        May          5      108
# 12  2023   November         11      170
# 13  2023    October         10      184
# 14  2023  September          9       87
# 15  2024      April          4      167
# 16  2024     August          8       80
# 17  2024   December         12       56
# 18  2024   February          2      199
# 19  2024    January          1       82
# 20  2024       July          7       51
# 21  2024       June          6       37
# ...

# %%
time = []
for i in range(timeline.shape[0]):
    time.append(timeline['month'][i] + "-" + str(timeline['year'][i]))

# %%
timeline['time'] = time

# %%
timeline
# Out:
#     year      month  month_sum  message            time
# 0   2022   December         12       97   December-2022
# 1   2022   November         11      272   November-2022
# 2   2022    October         10       33    October-2022
# 3   2023      April          4      153      April-2023
# 4   2023     August          8       78     August-2023
# 5   2023   December         12      123   December-2023
# 6   2023   February          2       53   February-2023
# 7   2023    January          1      120    January-2023
# 8   2023       July          7       48       July-2023
# 9   2023       June          6      104       June-2023
# 10  2023      March          3      144      March-2023
# 11  2023        May          5      108        May-2023
# 12  2023   November         11      170   November-2023
# 13  2023    October         10      184    October-2023
# 14  2023  September          9       87  September-2023
# 15  2024      April          4      167      April-2024
# ...

# %%
plt.plot(timeline['time'], timeline['message'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['only_date'] = df['date'].dt.date

# %%
daily_timeline = df.groupby(['only_date']).count()['message'].reset_index()

# %%
plt.plot(daily_timeline['only_date'], daily_timeline['message'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['day_name'] = df['date'].dt.day_name()

# %%
df['day_name'].value_counts()
# Out:
# day_name
# Wednesday    764
# Tuesday      686
# Thursday     666
# Monday       636
# Friday       579
# Saturday     347
# Sunday       225
# Name: count, dtype: int64

# %%
plt.bar(df['day_name'].value_counts().index, df['day_name'].value_counts().values)
# Out:
# <BarContainer object of 7 artists>

# %%
df['month_name'] = df['date'].dt.month_name()

# %%
df['month_name'].value_counts()
# Out:
# month_name
# November     577
# April        460
# February     432
# March        432
# October      370
# January      319
# May          313
# December     276
# September    238
# August       181
# June         173
# July         132
# Name: count, dtype: int64

# %%
plt.bar(df['month_name'].value_counts().index, df['month_name'].value_counts().values)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#                  date                user  \
# 0 2022-10-31 16:20:00  group_notification
# 1 2022-10-31 16:20:00  group_notification
# 2 2022-10-31 16:20:00  group_notification
# 3 2022-10-31 16:21:00  group_notification
# 4 2022-10-31 16:21:00  group_notification
#
#                                              message  year    month  day  \
# 0  Messages and calls are end-to-end encrypted. O...  2022  October   31
# 1       BCIIT created group "BCA-Students-2022-25"\n  2022  October   31
# 2                                  BCIIT added you\n  2022  October   31
# 3                     BCIIT added ~ Aniket Singhal\n  2022  October   31
# 4                      BCIIT added ~ Anmol Dhingra\n  2022  October   31
#
#    hour  minute  month_sum   only_date day_name month_name
# 0    16      20         10  2022-10-31   Monday    October
# 1    16      20         10  2022-10-31   Monday    October
# 2    16      20         10  2022-10-31   Monday    October
# ...

# %%
period = []

for hour in df[['day_name', 'hour']]['hour']:
    if hour == 23:
        period.append(str(hour) + "-" + str('00'))
    elif hour == 0:
        period.append(str('00') + "-" + str(hour + 1))
    else:
        period.append(str(hour) + "-" + str(hour + 1))

df['period'] = period

# %%
df.sample(5)['period']
# Out:
# 2362    15-16
# 1972    21-22
# 2957    10-11
# 1258    10-11
# 2764    17-18
# Name: period, dtype: object

# %%
import seaborn as sns

heatmap_data = df.pivot_table(index='day_name', columns='period', values='message', aggfunc='count').fillna(0)
heatmap_data = heatmap_data.reindex(sorted(heatmap_data.columns, key=lambda x: int(x.split('-')[0])), axis=1)

plt.figure(figsize=(20, 6))
sns.heatmap(heatmap_data)
plt.yticks(rotation='horizontal')
plt.show()

# %%
df.pivot_table(index='day_name', columns='period', values='message', aggfunc='count').fillna(0)
# Out:
# period     00-1  1-2  10-11  11-12  12-13  13-14  14-15  15-16  16-17  17-18  \
# day_name
# Friday      2.0  1.0   55.0   56.0   51.0   58.0   39.0   42.0   33.0   29.0
# Monday     16.0  1.0   50.0   45.0   59.0   57.0   55.0   52.0   59.0   35.0
# Saturday    1.0  1.0   20.0   22.0   40.0   22.0   37.0   29.0   30.0   19.0
# Sunday      4.0  1.0   12.0   11.0   11.0   10.0   23.0   14.0   17.0   10.0
# Thursday    1.0  1.0   64.0   53.0   53.0   52.0   52.0   62.0   73.0   26.0
# Tuesday     8.0  2.0   43.0   53.0   52.0   43.0   61.0   71.0   62.0   48.0
# Wednesday   5.0  0.0   63.0   61.0   65.0   57.0   66.0  107.0   42.0   36.0
#
# period     ...  20-21  21-22  22-23  23-00  3-4  5-6  6-7   7-8   8-9  9-10
# day_name   ...
# Friday     ...   11.0   30.0   15.0    6.0  1.0  1.0  0.0   3.0  33.0  74.0
# Monday     ...    6.0   43.0   15.0    5.0  0.0  1.0  1.0   4.0  27.0  36.0
# Saturday   ...    7.0   16.0    8.0    4.0  0.0  1.0  1.0  10.0   7.0  34.0
# ...
